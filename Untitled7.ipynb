# %% [markdown]
# <a href="https://colab.research.google.com/github/moamenkhalaf97/code/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
#from google.colab

# %%
img=cv2.imread('/content/img-process.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x100>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=200x100>

# %%
gray.shape
# Out:
# (100, 200)

# %%
img=cv2.imread('/content/page-book.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x155>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %%
value,thresh=cv2.threshold(gray,138,255,cv2.THRESH_BINARY)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=500x155>

# %%
value
# Out:
# 138.0

# %%
value,otsu=cv2.threshold(gray,0,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
cv2_imshow(otsu)
print(value)
# Out:
# <PIL.Image.Image image mode=L size=500x155>
# 138.0

# %%
img=cv2.imread('/content/recipe01.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=679x418>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=679x418>

# %%
value,thresh=cv2.threshold(gray,119,255,cv2.THRESH_BINARY)
cv2_imshow(thresh)
print(value)
# Out:
# <PIL.Image.Image image mode=L size=679x418>
# 119.0

# %%
value,otsu=cv2.threshold(gray,0,255,cv2.THRESH_BINARY |cv2.THRESH_OTSU)
cv2_imshow(otsu)
print(value)
# Out:
# <PIL.Image.Image image mode=L size=679x418>
# 119.0

# %%
img=cv2.imread('/content/book02.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=589x194>

# %%
 gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=589x194>

# %%
value,otsu=cv2.threshold(gray,0,255,cv2.THRESH_BINARY |cv2.THRESH_OTSU)
cv2_imshow(otsu)
print(value)
# Out:
# <PIL.Image.Image image mode=L size=589x194>
# 147.0

# %%
value,thresh=cv2.threshold(gray,147,255,cv2.THRESH_BINARY)
cv2_imshow(thresh)
print(value)
# Out:
# <PIL.Image.Image image mode=L size=589x194>
# 147.0

# %%
adaptive_average=cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,7)
cv2_imshow(adaptive_average)
# Out:
# <PIL.Image.Image image mode=L size=589x194>

# %%
img=cv2.imread('/content/book_adaptative.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x412>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=600x412>

# %%
adaptive_gaussian=cv2.adaptiveThreshold (gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,8)
cv2_imshow(adaptive_gaussian)
# Out:
# <PIL.Image.Image image mode=L size=600x412>

# %%
img=cv2.imread('/content/img-process.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x100>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=200x100>

# %%
img.shape,gray.shape
# Out:
# ((100, 200, 3), (100, 200))

# %%
gray
# Out:
# array([[ 68,  70,  72, ...,  76,  74,  74],
#        [ 68,  70,  73, ...,  75,  74,  77],
#        [ 70,  70,  72, ...,  74,  73,  76],
#        ...,
#        [ 67,  69,  82, ..., 123, 123, 124],
#        [ 70,  76,  92, ..., 124, 124, 125],
#        [ 70,  70,  80, ..., 123, 122, 123]], dtype=uint8)

# %%
invert=cv2.bitwise_not(gray)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=200x100>

# %%
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=589x194>

# %%
invert=255-thresh
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=589x194>

# %%
cv2_imshow(gray)
gray.shape
# Out:
# <PIL.Image.Image image mode=L size=200x100>
# (100, 200)

# %%
increase=cv2.resize(gray,None,fx=1.2,fy=1.4,interpolation=cv2.INTER_CUBIC)
cv2_imshow(increase)
# Out:
# <PIL.Image.Image image mode=L size=240x140>

# %%
increase.shape
# Out:
# (140, 240)

# %%
decrease=cv2.resize(gray,None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
cv2_imshow(decrease)
# Out:
# <PIL.Image.Image image mode=L size=100x50>

# %%
decrease.shape
# Out:
# (50, 100)

# %%
img=cv2.imread('/content/text-opencv.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x333>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=500x333>

# %%
np.ones((3,3),np.uint8)
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]], dtype=uint8)

# %%
erosion=cv2.erode(gray,np.ones((3,3),np.uint8))
cv2_imshow(erosion)
# Out:
# <PIL.Image.Image image mode=L size=500x333>

# %%
##dilation
dilation=cv2.dilate(gray,np.ones((3,3),np.uint8))
cv2_imshow(dilation)
# Out:
# <PIL.Image.Image image mode=L size=500x333>

# %%
erosion=cv2.erode(gray,np.ones((3,3),np.uint8))
opening=cv2.dilate(erosion,np.ones((3,3),np.uint8))
cv2_imshow(gray)
cv2_imshow(erosion)
cv2_imshow(opening)
# Out:
# <PIL.Image.Image image mode=L size=500x333>
# <PIL.Image.Image image mode=L size=500x333>
# <PIL.Image.Image image mode=L size=500x333>

# %%
img=cv2.imread('/content/text-opencv2.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x333>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=500x333>

# %%
cv2_imshow(gray)
dilation=cv2.dilate(gray,np.ones((2,2),np.uint8))
cv2_imshow(dilation)
closing=cv2.erode(dilation,np.ones((2,2),np.uint8))
cv2_imshow(closing)
# Out:
# <PIL.Image.Image image mode=L size=500x333>
# <PIL.Image.Image image mode=L size=500x333>
# <PIL.Image.Image image mode=L size=500x333>

# %%
 img=cv2.imread('/content/test_noise.jpg')
 gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
 cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=402x66>

# %%
average_blur=cv2.blur(gray,(3,3))
cv2_imshow(average_blur)
# Out:
# <PIL.Image.Image image mode=L size=402x66>

# %%
 gaussian_blur=cv2.GaussianBlur(gray,(3,3),0)
 cv2_imshow(gaussian_blur)
# Out:
# <PIL.Image.Image image mode=L size=402x66>

# %%
median_blur=cv2.medianBlur(gray,3)
cv2_imshow(median_blur)
# Out:
# <PIL.Image.Image image mode=L size=402x66>

# %%
bilateral_filter=cv2.bilateralFilter(gray,15,50,50)
cv2_imshow(bilateral_filter)
# Out:
# <PIL.Image.Image image mode=L size=402x66>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 0s (11.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
import pytesseract

# %%
# !mkdir tessdata
# !wget -O ./tessdata/por.traineddata https://github.com/tesseract-ocr/tessdata/blob/main/por.traineddata?raw=true
# !wget -O ./tessdata/eng.traineddata https://github.com/tesseract-ocr/tessdata/blob/main/eng.traineddata?raw=true
# Out:
# --2024-06-22 12:52:18--  https://github.com/tesseract-ocr/tessdata/blob/main/por.traineddata?raw=true
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/tesseract-ocr/tessdata/raw/main/por.traineddata [following]
# --2024-06-22 12:52:18--  https://github.com/tesseract-ocr/tessdata/raw/main/por.traineddata
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/tesseract-ocr/tessdata/main/por.traineddata [following]
# --2024-06-22 12:52:18--  https://raw.githubusercontent.com/tesseract-ocr/tessdata/main/por.traineddata
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
config_tesseract='--tessdata-dir tessdata'
text=pytesseract.image_to_string(average_blur,lang='por',config=config_tesseract)
print(text)
# Out:
# — REVOLUÇÃO CIENTÍFICA 69

# %%
config_tesseract='--tessdata-dir tessdata'
text=pytesseract.image_to_string(gaussian_blur,lang='por',config=config_tesseract)
print(text)

# %%
config_tesseract='--tessdata-dir tessdata'
text=pytesseract.image_to_string(median_blur,lang='por',config=config_tesseract)
print(text)
# Out:
# — REVOLUÇÃO CIENTÍFICA 59

# %%
config_tesseract='--tessdata-dir tessdata'
text=pytesseract.image_to_string(bilateral_filter,lang='por',config=config_tesseract)
print(text)
# Out:
# REVOLUÇÃO CIENTÍFICA 59

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from imutils.object_detection import non_max_suppression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/drive-download-20240619T133022Z-001/Models/frozen_east_text_detection.pb ./

# %%
# !cp -R /content/drive/MyDrive/drive-download-20240619T133022Z-001/Images ./

# %%
detector='/content/frozen_east_text_detection.pb'
width,height=320,320
img='/content/Images/cup.jpg'
min_confidence=0.9

# %%
img=cv2.imread(image)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=750x480>

# %%
original=img.copy()
img.shape
# Out:
# (480, 750, 3)

# %%
H=img.shape[0]
W=img.shape[1]
print(H,W)
# Out:
# 480 750

# %%
proportion_W=W/float(width)
proportion_H=H/float(height)
print(proportion_W,proportion_H)
# Out:
# 2.34375 1.5

# %%
img=cv2.resize(img,(width,height))
H=img.shape[0]
W=img.shape[1]
print(H,W)
# Out:
# 320 320

# %%
cv2_imshow(img)
img.shape
# Out:
# <PIL.Image.Image image mode=RGB size=320x320>
# (320, 320, 3)

# %%
#Load the NN
layers_names=['feature_fusion/Conv_7/Sigmoid','feature_fusion/concat_3']
net=cv2.dnn.readNet(detector)

# %%
img.shape
# Out:
# (320, 320, 3)

# %%
blob=cv2.dnn.blobFromImage(img,1.0,(W,H),swapRB=True,crop=False)

# %%
blob.shape
# Out:
# (1, 3, 320, 320)

# %%
net.setInput(blob)
scores,geometry=net.forward(layers_names)

# %%
scores
# Out:
# array([[[[1.4775183e-07, 5.3355325e-07, 6.1831190e-07, ...,
#           2.3887444e-06, 2.1422467e-07, 1.9741562e-06],
#          [2.2155248e-07, 8.2297476e-08, 1.5269326e-07, ...,
#           3.8021703e-06, 2.4969086e-07, 2.0974837e-06],
#          [2.4107598e-07, 2.5650635e-07, 6.7496660e-07, ...,
#           4.4842459e-06, 6.0891395e-08, 2.5159140e-06],
#          ...,
#          [5.1902941e-07, 1.3470725e-07, 3.8078490e-08, ...,
#           1.7954446e-06, 7.7535549e-07, 5.4700849e-06],
#          [2.8565972e-07, 8.5580076e-08, 1.1289849e-07, ...,
#           1.1354846e-06, 9.0157494e-07, 5.0782419e-06],
#          [7.2199100e-08, 8.4333314e-09, 5.4603602e-09, ...,
#           1.9142327e-07, 3.1659505e-07, 1.0240367e-07]]]], dtype=float32)

# %%
geometry
# Out:
# array([[[[ 1.54848892e+02,  1.01938675e+02,  1.08211121e+02, ...,
#            1.33965591e+02,  1.27577316e+02,  1.46967972e+02],
#          [ 1.19407852e+02,  6.46941986e+01,  7.18581772e+01, ...,
#            9.02676010e+01,  8.52865829e+01,  1.03320297e+02],
#          [ 1.22548691e+02,  6.90612030e+01,  7.86800308e+01, ...,
#            1.06369835e+02,  1.01670235e+02,  1.14973686e+02],
#          ...,
#          [ 1.16457314e+02,  4.99966507e+01,  3.75176544e+01, ...,
#            8.21259842e+01,  8.12639847e+01,  1.21695618e+02],
#          [ 1.27623383e+02,  5.88199654e+01,  4.84033051e+01, ...,
#            8.31772232e+01,  8.09340973e+01,  1.11183907e+02],
#          [ 1.26661522e+02,  7.53629608e+01,  6.93248215e+01, ...,
#            1.27025345e+02,  1.18697968e+02,  1.47223724e+02]],
#
#         [[ 1.09559761e+02,  9.52128754e+01,  9.08699265e+01, ...,
#            1.00495575e+02,  9.43882065e+01,  1.12618622e+02],
# ...

# %%
scores.shape
# Out:
# (1, 1, 80, 80)

# %%
scores.shape[2:4]
# Out:
# (80, 80)

# %%
rows,columns=scores.shape[2:4]
print(rows,columns)
# Out:
# 80 80

# %%
boxes=[]
confidences=[]

# %%
def geometric_data(geometry,y):
  xData0=geometry[0,0,y]
  xData1=geometry[0,1,y]
  xData2=geometry[0,2,y]
  xData3=geometry[0,3,y]
  angles_Data=geometry[0,4,y]
  return angles_Data,xData0,xData1,xData2,xData3

# %%
def geometric_calcultaion(angles_data,xData0,xData1,xData2,xData3):
  (offsetX,offsetY)=(x*4.0,y*4.0)
  angle=angles_Data[x]
  cos=np.cos(angle)
  sin=np.sin(angle)
  h=xData0[x]+xData2[x]
  w=xData1[x]+xData3[x]

  endX=int(offsetX+(cos*xData1[x])+(sin*xData2[x]))
  endY=int(offsetY-(sin*xData1[x])+(cos*xData2[x]))
  beginX=int(endX-w)
  beginY=int(endY-h)

  return beginX,beginY,endX,endY

# %%
for y in range(0,rows):
  data_scores=scores[0,0,y]
  angles_Data,xData0,xData1,xData2,xData3=geometric_data(geometry,y)
  print(data_scores)
  print('-----------')
  print(angles_Data,xData0,xData1,xData2,xData3)
  for x in range(0,columns):
    if data_scores[x]<min_confidence:
      continue

    beginX,beginY,endX,endY=geometric_calcultaion(angles_Data,xData0,xData1,xData2,xData3)
    boxes.append([beginX,beginY,endX,endY])
    confidences.append(data_scores[x])
# Out:
# Streaming output truncated to the last 5000 lines.
#   39.552578  40.31787   40.30069   39.943687  40.237045  41.16934
#   43.121773  43.184216  45.071045  47.472614  51.71485   51.634556
#   57.874218  68.4504    83.93349   96.10226   99.68688   98.03901
#   88.428276 106.94082 ] [ 79.75164    44.924248   42.91236    42.663334   42.13097    41.25182
#   40.902058   40.480595   40.30223    40.540928   40.818172   41.438
#   41.823395   42.288147   42.960106   43.754395   44.80413    46.14612
#   46.70641    46.67945    46.023434   46.329998   47.54156    47.97628
#   48.076984   47.840446   47.74675    47.709766   47.556576   47.288517
#   47.09109    46.932842   46.47667    45.963745   45.701473   45.75318
#   46.655434   47.375088   48.623676   48.168247   47.619076   46.83911
#   44.828228   45.355125   48.921635   47.693523   42.444077   34.812656
#   26.983723   17.981863   14.067345   14.3378725  15.379699   16.540314
# ...

# %%
confidences
# Out:
# [0.9995617,
#  0.99982554,
#  0.9997718,
#  0.9994678,
#  0.96625125,
#  0.96421045,
#  0.9993309,
#  0.99968016,
#  0.99951243]

# %%
boxes
# Out:
# [[156, 208, 190, 220],
#  [157, 208, 187, 220],
#  [157, 208, 186, 220],
#  [158, 207, 186, 220],
#  [156, 207, 187, 221],
#  [157, 207, 188, 220],
#  [158, 208, 187, 221],
#  [158, 208, 187, 221],
#  [157, 208, 188, 221]]

# %%
detections=non_max_suppression(np.array(boxes),probs=confidences)

# %%
detections
# Out:
# array([[157, 208, 187, 220]])

# %%
img_copy=original.copy()
for(beginX,beginY,endX,endY) in detections:
  beginX=int(beginX*proportion_W)
  beginY=int(beginY*proportion_H)
  endX=int(endX*proportion_W)
  endY=int(endY*proportion_H)

  region_of_interest=img_copy[beginY:endY,beginX:endX]
  text=pytesseract.image_to_string(region_of_interest,lang='eng',config=config_tesseract)
  print(text)
  cv2.rectangle(original,(beginX,beginY),(endX,endY),(0,255,0),1)
cv2_imshow(original)
# Out:
# BEGIN.
# <PIL.Image.Image image mode=RGB size=750x480>

# %%
cv2_imshow(region_of_interest)
# Out:
# <PIL.Image.Image image mode=RGB size=71x18>

# %%
region_of_interest=cv2.resize(region_of_interest,None,fx=2.0,fy=2.0,interpolation=cv2.INTER_CUBIC)
cv2_imshow(region_of_interest)
# Out:
# <PIL.Image.Image image mode=RGB size=142x36>

# %%
#working with tessereact
# !tesseract --help-psm
# Out:
# Page segmentation modes:
#   0    Orientation and script detection (OSD) only.
#   1    Automatic page segmentation with OSD.
#   2    Automatic page segmentation, but no OSD, or OCR. (not implemented)
#   3    Fully automatic page segmentation, but no OSD. (Default)
#   4    Assume a single column of text of variable sizes.
#   5    Assume a single uniform block of vertically aligned text.
#   6    Assume a single uniform block of text.
#   7    Treat the image as a single text line.
#   8    Treat the image as a single word.
#   9    Treat the image as a single word in a circle.
#  10    Treat the image as a single character.
#  11    Sparse text. Find as much text as possible in no particular order.
#  12    Sparse text with OSD.
#  13    Raw line. Treat the image as a single text line,
#        bypassing hacks that are Tesseract-specific.

# %%
config_tesseract='--tessdata-dir tessdata --psm 7'

# %%
margin=3
img_copy=original.copy()
for(beginX,beginY,endX,endY) in detections:
  beginX=int(beginX*proportion_W)
  beginY=int(beginY*proportion_H)
  endX=int(endX*proportion_W)
  endY=int(endY*proportion_H)

  region_of_interest=img_copy[beginY:endY,beginX:endX]
  cv2_imshow(region_of_interest)
  text=pytesseract.image_to_string(region_of_interest,lang='eng',config=config_tesseract)
  print(text)
  cv2.rectangle(original,(beginX-margin,beginY+margin),(endX+margin,endY+margin),(0,255,0),1)
cv2_imshow(original)
# Out:
# <PIL.Image.Image image mode=RGB size=71x18>
# BEGIN.
# <PIL.Image.Image image mode=RGB size=750x480>
